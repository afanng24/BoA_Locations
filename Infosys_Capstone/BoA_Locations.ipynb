# %%
#import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import time
plt.style.use('ggplot')
from pathlib import Path
from collections import Counter
import csv

# %%
df = pd.read_csv('locations.csv')
# Out:
# C:\Users\afann\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (29) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#                                   ADDRESS BKCLASS  \
# 0                  75 North Market Street       N
# 1                196 South Wyoming Avenue       N
# 2                       2 W Swedesford Rd       N
# 3                  1993 S Eighty Eight Rd      NM
# 4                        1310 Liberty St.       N
# ...                                   ...     ...
# 83741                      2381 Post Road      SB
# 83742                   1860 Payne Street       N
# 83743                      122 Broadway N       N
# 83744  1135 Muhlenbergia Drive, Suite 102       N
# 83745            100 East Hamilton Street      NM
#
#                                               CBSA  \
# 0                       Scranton--Wilkes-Barre, PA
# 1                       Scranton--Wilkes-Barre, PA
# 2      Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 3                                              NaN
# 4                                     Oil City, PA
# ...

# %%
df.count()
# Out:
# ADDRESS            83746
# BKCLASS            83746
# CBSA               74685
# CBSA_DIV           19529
# CBSA_DIV_FLG       83746
# CBSA_DIV_NO        28590
# CBSA_METRO         83746
# CBSA_METRO_FLG     83746
# CBSA_METRO_NAME    65428
# CBSA_MICRO_FLG     83746
# CBSA_NO            83746
# CERT               83746
# CITY               83746
# COUNTY             83746
# CSA                60646
# CSA_FLG            83746
# CSA_NO             69707
# ESTYMD             83746
# FI_UNINUM          83746
# MAINOFF            83746
# NAME               83746
# OFFNAME            83746
# OFFNUM             83746
# RUNDATE            83746
# SERVTYPE           83746
# STALP              82936
# STCNTY             83746
# STNAME             82936
# UNINUM             83746
# ZIP                83746
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83746 entries, 0 to 83745
# Data columns (total 30 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ADDRESS          83746 non-null  object
#  1   BKCLASS          83746 non-null  object
#  2   CBSA             74685 non-null  object
#  3   CBSA_DIV         19529 non-null  object
#  4   CBSA_DIV_FLG     83746 non-null  int64
#  5   CBSA_DIV_NO      28590 non-null  float64
#  6   CBSA_METRO       83746 non-null  int64
#  7   CBSA_METRO_FLG   83746 non-null  int64
#  8   CBSA_METRO_NAME  65428 non-null  object
#  9   CBSA_MICRO_FLG   83746 non-null  int64
#  10  CBSA_NO          83746 non-null  int64
#  11  CERT             83746 non-null  int64
#  12  CITY             83746 non-null  object
#  13  COUNTY           83746 non-null  object
#  14  CSA              60646 non-null  object
#  15  CSA_FLG          83746 non-null  int64
# ...

# %%
df_data_dropped = df.dropna(how='all')

# %%
df_data_dropped
# Out:
#                                   ADDRESS BKCLASS  \
# 0                  75 North Market Street       N
# 1                196 South Wyoming Avenue       N
# 2                       2 W Swedesford Rd       N
# 3                  1993 S Eighty Eight Rd      NM
# 4                        1310 Liberty St.       N
# ...                                   ...     ...
# 83741                      2381 Post Road      SB
# 83742                   1860 Payne Street       N
# 83743                      122 Broadway N       N
# 83744  1135 Muhlenbergia Drive, Suite 102       N
# 83745            100 East Hamilton Street      NM
#
#                                               CBSA  \
# 0                       Scranton--Wilkes-Barre, PA
# 1                       Scranton--Wilkes-Barre, PA
# 2      Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 3                                              NaN
# 4                                     Oil City, PA
# ...

# %%
df_columns_dropped = df_data_dropped.where(df_data_dropped.NAME =='Bank of America, National Association')

# %%
df_columns_dropped.head(150)
# Out:
#                ADDRESS BKCLASS                                 CBSA CBSA_DIV  \
# 0                  NaN     NaN                                  NaN      NaN
# 1                  NaN     NaN                                  NaN      NaN
# 2                  NaN     NaN                                  NaN      NaN
# 3                  NaN     NaN                                  NaN      NaN
# 4                  NaN     NaN                                  NaN      NaN
# ..                 ...     ...                                  ...      ...
# 145  16209 Bryant Road       N  Portland-Vancouver-Hillsboro, OR-WA      NaN
# 146  600 North Main St       N      Charleston-North Charleston, SC      NaN
# 147                NaN     NaN                                  NaN      NaN
# 148                NaN     NaN                                  NaN      NaN
# 149                NaN     NaN                                  NaN      NaN
#
# ...

# %%
df_columns_dropped.dropna()
# Out:
#                        ADDRESS BKCLASS  \
# 195        8788 Georgia Avenue       N
# 263               16 School St       N
# 317    6331 West Archer Avenue       N
# 384            24120 Ford Road       N
# 385       3031 West Grand Blvd       N
# ...                        ...     ...
# 82910         114 West 47th St       N
# 82960  2 South Michigan Avenue       N
# 83126       5636 Lemmon Avenue       N
# 83203    200 Hudson St Ste 162       N
# 83371  4001 Cross Timbers Road       N
#
#                                                CBSA  \
# 195    Washington-Arlington-Alexandria, DC-VA-MD-WV
# 263                  Boston-Cambridge-Newton, MA-NH
# 317              Chicago-Naperville-Elgin, IL-IN-WI
# 384                     Detroit-Warren-Dearborn, MI
# 385                     Detroit-Warren-Dearborn, MI
# ...                                             ...
# 82910         New York-Newark-Jersey City, NY-NJ-PA
# 82960            Chicago-Naperville-Elgin, IL-IN-WI
# ...

# %%
boa_df = df_columns_dropped.dropna()

# %%
boa_df
# Out:
#                        ADDRESS BKCLASS  \
# 195        8788 Georgia Avenue       N
# 263               16 School St       N
# 317    6331 West Archer Avenue       N
# 384            24120 Ford Road       N
# 385       3031 West Grand Blvd       N
# ...                        ...     ...
# 82910         114 West 47th St       N
# 82960  2 South Michigan Avenue       N
# 83126       5636 Lemmon Avenue       N
# 83203    200 Hudson St Ste 162       N
# 83371  4001 Cross Timbers Road       N
#
#                                                CBSA  \
# 195    Washington-Arlington-Alexandria, DC-VA-MD-WV
# 263                  Boston-Cambridge-Newton, MA-NH
# 317              Chicago-Naperville-Elgin, IL-IN-WI
# 384                     Detroit-Warren-Dearborn, MI
# 385                     Detroit-Warren-Dearborn, MI
# ...                                             ...
# 82910         New York-Newark-Jersey City, NY-NJ-PA
# 82960            Chicago-Naperville-Elgin, IL-IN-WI
# ...

# %%
boa_df.head()
# Out:
#                      ADDRESS BKCLASS  \
# 195      8788 Georgia Avenue       N
# 263             16 School St       N
# 317  6331 West Archer Avenue       N
# 384          24120 Ford Road       N
# 385     3031 West Grand Blvd       N
#
#                                              CBSA  \
# 195  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 263                Boston-Cambridge-Newton, MA-NH
# 317            Chicago-Naperville-Elgin, IL-IN-WI
# 384                   Detroit-Warren-Dearborn, MI
# 385                   Detroit-Warren-Dearborn, MI
#
#                                  CBSA_DIV  CBSA_DIV_FLG  CBSA_DIV_NO  \
# 195  Frederick-Gaithersburg-Rockville, MD           1.0      23224.0
# 263                            Boston, MA           1.0      14454.0
# 317       Chicago-Naperville-Evanston, IL           1.0      16984.0
# 384          Detroit-Dearborn-Livonia, MI           1.0      19804.0
# 385          Detroit-Dearborn-Livonia, MI           1.0      19804.0
#
# ...
